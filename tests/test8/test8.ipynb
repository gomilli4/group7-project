# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0   time  num-herbivores       speed  turn-speed       fov
# 0           0  0.000              40  102.190482    3.177029  2.974221  \
# 1           1  0.001              40  102.190482    3.177029  2.974221
# 2           2  0.002              40  102.190482    3.177029  2.974221
# 3           3  0.003              40  102.190482    3.177029  2.974221
# 4           4  0.004              40  102.190482    3.177029  2.974221
#
#    view-dist  max-energy  metabolism-rate  find-mate-rate  max-desire-to-mate
# 0  150.26154  164.050909         0.234873        2.542737            57.27363
# 1  150.26154  164.050909         0.234873        2.542737            57.27363
# 2  150.26154  164.050909         0.234873        2.542737            57.27363
# 3  150.26154  164.050909         0.234873        2.542737            57.27363
# 4  150.26154  164.050909         0.234873        2.542737            57.27363

# %%
plt.plot(data['time'], data['num-herbivores'])
plt.grid()

# %%
plt.plot(data['time'], data['metabolism-rate'])

# %%
plt.plot(data['time'], data['speed'])

# %%
plt.plot(data['time'], data['turn-speed'])

# %%
plt.plot(data['time'], data['fov']*180/np.pi)

# %%
plt.plot(data['time'], data['view-dist'])

# %%
plt.plot(data['time'], data['max-energy'])

# %%
plt.plot(data['time'], data['find-mate-rate'])

# %%
plt.plot(data['time'], data['max-desire-to-mate'])
