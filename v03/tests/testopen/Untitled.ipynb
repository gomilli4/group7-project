# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')
plt.plot(data['time'], data['num-herbivores'], label='Prey')
plt.plot(data['time'], data['num-carnivores'], label='Predators')
plt.legend()
plt.grid()

# %%
plt.plot(data['time'], data['speed'])
plt.grid()

# %%
plt.plot(data['time'], data['turn-speed'])
plt.grid()

# %%
plt.plot(data['time'], data['fov']*180/np.pi)
plt.plot(data['time'], data['max-energy'])
plt.grid()

# %%
plt.plot(data['time'], data['metabolism-rate'])
plt.grid()

# %%
plt.plot(data['time'], data['find-mate-rate'])
plt.grid()

# %%
plt.plot(data['time'], data['max-desire-to-mate'])
plt.grid()
